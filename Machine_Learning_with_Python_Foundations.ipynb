# %% [markdown]
# <a href="https://colab.research.google.com/github/BarryDeCicco/LinkedIn_Machine_Learning_with_Python_Series/blob/main/Machine_Learning_with_Python_Foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Testing Git connection on 14 July 2026

# %%
import pandas as pd

# %%
members = ["Brazil", "Russia", "India", "China", "South Africa"]
brics1 = pd.Series(members)

# %%
type(members)
# Out:
# list

# %%
type(brics1)
# Out:
# pandas.core.series.Series

# %%
brics1
# Out:
# 0          Brazil
# 1          Russia
# 2           India
# 3           China
# 4    South Africa
# dtype: object

# %% [markdown]
# df.info()
# df.head()
# df.tail()
# df.[["colname"]].describe()
# df.[["colname"]].value_counts()
# df.[["colname"]].value_counts(normalize=True)
# df.groupby("group_colname").[["colname_for_mean"]].mean().sort_values(by="column_to_sort_by")
